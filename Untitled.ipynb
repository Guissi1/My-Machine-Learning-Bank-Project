# %%
#Chargement des bibliothèques
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import VarianceThreshold
from sklearn.feature_selection import SelectFromModel
from sklearn.utils import shuffle
from sklearn.ensemble import RandomForestClassifier
pd.set_option('display.max_columns', 100)

# %%
import csv
bank = open('bank_df3.csv')
bank = pd.read_csv('bank_df3.csv',delimiter=';')
# Now you can check the shape of the DataFrame
?????????????

bank [['age','job','marital','education','default','balance','housing','loan','contact','day','month','duration','campaign','pdays','previous','poutcome','target']] = bank['age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"'].str.split(';', expand = True)
bank = bank.drop(columns=['age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"'])
updated_file_path = 'updatd_bank.csv'
bank.to_csv(updated_file_path, index = False)

# %%
bank
# Out:
#        age             job     marital    education default balance housing  \
# 0       58    "management"   "married"   "tertiary"    "no"    2143   "yes"
# 1       44    "technician"    "single"  "secondary"    "no"      29   "yes"
# 2       33  "entrepreneur"   "married"  "secondary"    "no"       2   "yes"
# 3      NaN             NaN         NaN          NaN     NaN     NaN     NaN
# 4       33       "unknown"    "single"    "unknown"    "no"       1    "no"
# ...    ...             ...         ...          ...     ...     ...     ...
# 80074   51    "technician"   "married"   "tertiary"    "no"     825    "no"
# 80075   71       "retired"  "divorced"    "primary"    "no"    1729    "no"
# 80076   72       "retired"   "married"  "secondary"    "no"    5715    "no"
# 80077   57   "blue-collar"   "married"  "secondary"    "no"     668    "no"
# 80078   37  "entrepreneur"   "married"  "secondary"    "no"    2971    "no"
#
# ...

# %%
data=bank

# %%
data.head()
# Out:
#    age             job    marital    education default balance housing   loan  \
# 0   58    "management"  "married"   "tertiary"    "no"    2143   "yes"   "no"
# 1   44    "technician"   "single"  "secondary"    "no"      29   "yes"   "no"
# 2   33  "entrepreneur"  "married"  "secondary"    "no"       2   "yes"  "yes"
# 3  NaN             NaN        NaN          NaN     NaN     NaN     NaN    NaN
# 4   33       "unknown"   "single"    "unknown"    "no"       1    "no"   "no"
#
#      contact  day  month duration campaign pdays previous   poutcome target
# 0  "unknown"    5  "may"      261        1    -1        0  "unknown"   "no"
# 1  "unknown"    5  "may"      151        1    -1        0  "unknown"   "no"
# 2  "unknown"    5  "may"       76        1    -1        0  "unknown"   "no"
# 3        NaN  NaN    NaN      NaN      NaN   NaN      NaN        NaN    NaN
# 4  "unknown"    5  "may"      198        1    -1        0  "unknown"   "no"

# %%
data.tail()
# Out:
#       age             job     marital    education default balance housing  \
# 80074  51    "technician"   "married"   "tertiary"    "no"     825    "no"
# 80075  71       "retired"  "divorced"    "primary"    "no"    1729    "no"
# 80076  72       "retired"   "married"  "secondary"    "no"    5715    "no"
# 80077  57   "blue-collar"   "married"  "secondary"    "no"     668    "no"
# 80078  37  "entrepreneur"   "married"  "secondary"    "no"    2971    "no"
#
#        loan      contact day  month duration campaign pdays previous  \
# 80074  "no"   "cellular"  17  "nov"      977        3    -1        0
# 80075  "no"   "cellular"  17  "nov"      456        2    -1        0
# 80076  "no"   "cellular"  17  "nov"     1127        5   184        3
# 80077  "no"  "telephone"  17  "nov"      508        4    -1        0
# 80078  "no"   "cellular"  17  "nov"      361        2   188       11
#
#         poutcome target
# 80074  "unknown"  "yes"
# 80075  "unknown"  "yes"
# ...

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'target'],
#       dtype='object')

# %%
data.shape
# Out:
# (80079, 17)

# %%
data.info
# Out:
# <bound method DataFrame.info of        age             job     marital    education default balance housing  \
# 0       58    "management"   "married"   "tertiary"    "no"    2143   "yes"
# 1       44    "technician"    "single"  "secondary"    "no"      29   "yes"
# 2       33  "entrepreneur"   "married"  "secondary"    "no"       2   "yes"
# 3      NaN             NaN         NaN          NaN     NaN     NaN     NaN
# 4       33       "unknown"    "single"    "unknown"    "no"       1    "no"
# ...    ...             ...         ...          ...     ...     ...     ...
# 80074   51    "technician"   "married"   "tertiary"    "no"     825    "no"
# 80075   71       "retired"  "divorced"    "primary"    "no"    1729    "no"
# 80076   72       "retired"   "married"  "secondary"    "no"    5715    "no"
# 80077   57   "blue-collar"   "married"  "secondary"    "no"     668    "no"
# 80078   37  "entrepreneur"   "married"  "secondary"    "no"    2971    "no"
#
# ...

# %%
bank.describe
# Out:
# <bound method NDFrame.describe of        age             job     marital    education default balance housing  \
# 0       58    "management"   "married"   "tertiary"    "no"    2143   "yes"
# 1       44    "technician"    "single"  "secondary"    "no"      29   "yes"
# 2       33  "entrepreneur"   "married"  "secondary"    "no"       2   "yes"
# 3      NaN             NaN         NaN          NaN     NaN     NaN     NaN
# 4       33       "unknown"    "single"    "unknown"    "no"       1    "no"
# ...    ...             ...         ...          ...     ...     ...     ...
# 80074   51    "technician"   "married"   "tertiary"    "no"     825    "no"
# 80075   71       "retired"  "divorced"    "primary"    "no"    1729    "no"
# 80076   72       "retired"   "married"  "secondary"    "no"    5715    "no"
# 80077   57   "blue-collar"   "married"  "secondary"    "no"     668    "no"
# 80078   37  "entrepreneur"   "married"  "secondary"    "no"    2971    "no"
#
# ...

# %%
data.nunique()
# Out:
# age            78
# job            13
# marital         4
# education       6
# default         2
# balance      6980
# housing         4
# loan            4
# contact         5
# day            32
# month          14
# duration     1544
# campaign       49
# pdays         554
# previous       40
# poutcome        4
# target          2
# dtype: int64

# %%
bank.drop_duplicates()
bank.shape
# Out:
# (80079, 17)

# %%
print(data.isna().sum())
# Out:
# age          16016
# job          16016
# marital      16016
# education    16016
# default      16016
# balance      16016
# housing      16016
# loan         16016
# contact      16016
# day          16016
# month        16016
# duration     16016
# campaign     16016
# pdays        16016
# previous     16017
# poutcome     16018
# target       16018
# dtype: int64

# %%
data = pd.DataFrame(data)
data=data.dropna()

# %%
print(data.isna().sum())

dropna?????
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# target       0
# dtype: int64

# %%
data.shape
# Out:
# (64061, 17)

# %%
print(data.groupby('target').size())
# Out:
# target
# "no"     55912
# "yes"     8149
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x=data['target'])
plt.show()

# %%
# Chargement des bibliothèques
# importer bibliothèque 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_curve, auc
import warnings # supress warnings
warnings.filterwarnings('ignore')

# %%
data.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'target'],
#       dtype='object')

# %%
data['target']
# Out:
# 0         "no"
# 1         "no"
# 2         "no"
# 4         "no"
# 5         "no"
#          ...
# 80074    "yes"
# 80075    "yes"
# 80076    "yes"
# 80077     "no"
# 80078     "no"
# Name: target, Length: 64061, dtype: object

# %%
# Remove double quotes and convert "no" to 0 and "yes" to 1
data['target'] = data['target'].str.strip('"').map({'no': 0, 'yes': 1})

# Calculate the correlation matrix
correlation_matrix = data.corr()

# Display the correlation of the 'y' column with other columns
print(correlation_matrix['target'])
# Out:
# target    1.0
# Name: target, dtype: float64

# %%
data
# Out:
#       age             job     marital    education default balance housing  \
# 0      58    "management"   "married"   "tertiary"    "no"    2143   "yes"
# 1      44    "technician"    "single"  "secondary"    "no"      29   "yes"
# 2      33  "entrepreneur"   "married"  "secondary"    "no"       2   "yes"
# 4      33       "unknown"    "single"    "unknown"    "no"       1    "no"
# 5      35    "management"   "married"   "tertiary"    "no"     231   "yes"
# ...    ..             ...         ...          ...     ...     ...     ...
# 80074  51    "technician"   "married"   "tertiary"    "no"     825    "no"
# 80075  71       "retired"  "divorced"    "primary"    "no"    1729    "no"
# 80076  72       "retired"   "married"  "secondary"    "no"    5715    "no"
# 80077  57   "blue-collar"   "married"  "secondary"    "no"     668    "no"
# 80078  37  "entrepreneur"   "married"  "secondary"    "no"    2971    "no"
#
# ...

# %%
data['job'].unique()
# Out:
# array(['"management"', '"technician"', '"entrepreneur"', '"unknown"',
#        '"retired"', '"admin."', '"services"', '"blue-collar"',
#        '"self-employed"', '"unemployed"', '"student"', '"housemaid"'],
#       dtype=object)

# %%
import pandas as pd

# Columns to apply one-hot encoding (excluding 'job', 'default', and 'housing')
columns_to_encode = ['default', 'housing','loan','poutcome']

# Perform one-hot encoding on the specified columns
onehot_encoded = pd.get_dummies(data[columns_to_encode], prefix=columns_to_encode)

# Drop the original columns from the DataFrame
data.drop(columns_to_encode, axis=1, inplace=True)

# Concatenate the one-hot encoded columns with the original DataFrame
data = pd.concat([data, onehot_encoded], axis=1)

# Display the modified DataFrame
print(data)
# Out:
#       age             job     marital    education balance      contact day  \
# 0      58    "management"   "married"   "tertiary"    2143    "unknown"   5
# 1      44    "technician"    "single"  "secondary"      29    "unknown"   5
# 2      33  "entrepreneur"   "married"  "secondary"       2    "unknown"   5
# 4      33       "unknown"    "single"    "unknown"       1    "unknown"   5
# 5      35    "management"   "married"   "tertiary"     231    "unknown"   5
# ...    ..             ...         ...          ...     ...          ...  ..
# 80074  51    "technician"   "married"   "tertiary"     825   "cellular"  17
# 80075  71       "retired"  "divorced"    "primary"    1729   "cellular"  17
# 80076  72       "retired"   "married"  "secondary"    5715   "cellular"  17
# 80077  57   "blue-collar"   "married"  "secondary"     668  "telephone"  17
# 80078  37  "entrepreneur"   "married"  "secondary"    2971   "cellular"  17
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the 'job' column using LabelEncoder
data['job'] = label_encoder.fit_transform(data['job'])
data['marital'] = label_encoder.fit_transform(data['marital'])
data['education'] = label_encoder.fit_transform(data['education'])
data['contact'] = label_encoder.fit_transform(data['contact'])
data['month'] = label_encoder.fit_transform(data['month'])





# Display the modified DataFrame with the encoded 'job' column
print(data)
# Out:
#       age  job  marital  education balance  contact day  month duration  \
# 0      58    4        1          2    2143        2   5      8      261
# 1      44    9        2          1      29        2   5      8      151
# 2      33    2        1          1       2        2   5      8       76
# 4      33   11        2          3       1        2   5      8      198
# 5      35    4        1          2     231        2   5      8      139
# ...    ..  ...      ...        ...     ...      ...  ..    ...      ...
# 80074  51    9        1          2     825        0  17      9      977
# 80075  71    5        0          0    1729        0  17      9      456
# 80076  72    5        1          1    5715        0  17      9     1127
# 80077  57    1        1          1     668        1  17      9      508
# 80078  37    2        1          1    2971        0  17      9      361
#
#       campaign pdays previous  target  default_"no"  default_"yes"  \
# ...

# %%
data
# Out:
#       age  job  marital  education balance  contact day  month duration  \
# 0      58    4        1          2    2143        2   5      8      261
# 1      44    9        2          1      29        2   5      8      151
# 2      33    2        1          1       2        2   5      8       76
# 4      33   11        2          3       1        2   5      8      198
# 5      35    4        1          2     231        2   5      8      139
# ...    ..  ...      ...        ...     ...      ...  ..    ...      ...
# 80074  51    9        1          2     825        0  17      9      977
# 80075  71    5        0          0    1729        0  17      9      456
# 80076  72    5        1          1    5715        0  17      9     1127
# 80077  57    1        1          1     668        1  17      9      508
# 80078  37    2        1          1    2971        0  17      9      361
#
#       campaign pdays previous  target  default_"no"  default_"yes"  \
# ...

# %%
# Calculate the correlation matrix
correlation_matrix = data.corr()

# Display the correlation of "default payment next month" with other columns
print(correlation_matrix['target'])
# Out:
# job                   0.038353
# marital               0.049169
# education             0.064673
# contact              -0.121906
# month                -0.005856
# target                1.000000
# default_"no"          0.024318
# default_"yes"        -0.024318
# housing_"no"          0.131795
# housing_"yes"        -0.131795
# loan_"no"             0.071511
# loan_"yes"           -0.071511
# poutcome_"failure"    0.000321
# poutcome_"other"      0.024587
# poutcome_"success"    0.306366
# poutcome_"unknown"   -0.156869
# Name: target, dtype: float64

# %%
import seaborn as sns
# heatmap of data
#to visualize the correlation between the features

plt.figure(figsize = (15, 8))

sns.heatmap(data.corr(), annot = True, linewidths = 2, linecolor = 'lightgrey')
plt.show()

# %%
data.describe()
# Out:
#                 job       marital     education       contact         month  \
# count  64061.000000  64061.000000  64061.000000  64061.000000  64061.000000
# mean       4.395061      1.168574      1.238367      0.466415      5.269306
# std        3.257322      0.608178      0.745076      0.801585      3.084637
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        1.000000      1.000000      1.000000      0.000000      3.000000
# 50%        4.000000      1.000000      1.000000      0.000000      5.000000
# 75%        7.000000      2.000000      2.000000      1.000000      8.000000
# max       11.000000      2.000000      3.000000      2.000000     11.000000
#
#              target  default_"no"  default_"yes"  housing_"no"  housing_"yes"  \
# count  64061.000000  64061.000000   64061.000000  64061.000000   64061.000000
# mean       0.127207      0.982267       0.017733      0.475890       0.524110
# ...

# %%
# Display the data types of all columns in the DataFrame
print(data.dtypes)
# Out:
# age                   object
# job                    int32
# marital                int32
# education              int32
# balance               object
# contact                int32
# day                   object
# month                  int32
# duration              object
# campaign              object
# pdays                 object
# previous              object
# target                 int64
# default_"no"           uint8
# default_"yes"          uint8
# housing_"no"           uint8
# housing_"yes"          uint8
# loan_"no"              uint8
# loan_"yes"             uint8
# poutcome_"failure"     uint8
# poutcome_"other"       uint8
# poutcome_"success"     uint8
# poutcome_"unknown"     uint8
# dtype: object

# %%
# Convert 'age' column from 'object' to 'int'
data['age'] = data['age'].astype(int)
data['duration'] = data['duration'].astype(int)
data['balance'] = data['balance'].astype(int)
data['campaign'] = data['campaign'].astype(int)
data['duration'] = data['duration'].astype(int)
data['day'] = data['day'].astype(int)

data['previous'] = data['previous'].astype(int)


data['pdays'] = data['pdays'].astype(int)

               


# Display the updated data types
print(data.dtypes)
# Out:
# age                   int32
# job                   int32
# marital               int32
# education             int32
# balance               int32
# contact               int32
# day                   int32
# month                 int32
# duration              int32
# campaign              int32
# pdays                 int32
# previous              int32
# target                int64
# default_"no"          uint8
# default_"yes"         uint8
# housing_"no"          uint8
# housing_"yes"         uint8
# loan_"no"             uint8
# loan_"yes"            uint8
# poutcome_"failure"    uint8
# poutcome_"other"      uint8
# poutcome_"success"    uint8
# poutcome_"unknown"    uint8
# dtype: object

# %%
for col in data.columns[:-1]:
    plt.figure()
    data.boxplot(column=col, by='target')
    plt.title(col)
    
plt.show()

# %%
X=data.drop(['target'],axis=1)
y=data[['target']]

# %%
# Count the occurrences of each class in the 'y' column
class_counts = y['target'].value_counts()

# Display the class counts
print(class_counts)
# Out:
# 0    55912
# 1     8149
# Name: target, dtype: int64

# %%
class_distribution = y.value_counts()

# Display class distribution
print("Class Distribution:")
print(class_distribution)

# Check if the data is balanced
balanced = (class_distribution.min() / class_distribution.max()) > 0.8

# Print result
if balanced:
    print("The data is balanced.")
else:
    print("The data is imbalanced.")
# Out:
# Class Distribution:
# target
# 0         55912
# 1          8149
# dtype: int64
# The data is imbalanced.

# %%
import matplotlib.pyplot as plt

# Plot the class distribution
class_counts.plot(kind='bar', color=['blue', 'orange'])
plt.title('Class Distribution')
plt.xlabel('Class')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
from imblearn.over_sampling import SMOTE

# Apply SMOTE to balance the data
sm = SMOTE()
X, y = sm.fit_resample(X, y)

# Create a balanced DataFrame
data_resembled = pd.concat([X, y], axis=1)

# %%
fig, ax1 = plt.subplots(1, 1, figsize= (10, 5))

y['target'].value_counts().plot(kind='bar', ax=ax1)
# Out:
# <AxesSubplot:>

# %%
#ACP
from sklearn.decomposition import PCA
# Create a PCA object with desired number of components
pca = PCA(n_components=2)

# Fit the PCA object to the selected features ( Train it )
pca.fit(X)

# Transform the selected features using the PCA ( Test it )
transformed_data = pca.transform(X)

# %%
transformed_data
# Out:
# array([[  570.96918487,  -110.70184617],
#        [-1543.08150184,  -219.82364649],
#        [-1570.11715578,  -294.79644912],
#        ...,
#        [ 3407.93449513,  -181.84012911],
#        [  788.95458202,  -217.61881389],
#        [ 3902.99164946,   -52.07362542]])

# %%
# Create a new DataFrame with the transformed data
pca_df = pd.DataFrame(data=transformed_data, columns=['PC1','PC2'])

# %%
pca_df
# Out:
#                 PC1         PC2
# 0        570.969185 -110.701846
# 1      -1543.081502 -219.823646
# 2      -1570.117156 -294.796449
# 3      -1571.066837 -172.817194
# 4      -1341.090406 -231.900185
# ...             ...         ...
# 111819    56.097630  218.451356
# 111820 -1663.073397 -188.781423
# 111821  3407.934495 -181.840129
# 111822   788.954582 -217.618814
# 111823  3902.991649  -52.073625
#
# [111824 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a scatter plot
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111, projection='3d')

# Extract PC1, PC2, and class labels from pca_df
x = pca_df['PC1']
y = pca_df['PC2']

# Scatter plot with colors based on class labels
scatter = ax.scatter(x, y, cmap='viridis')

# Add axis labels and a title
ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')  # Assuming there is also a PC3
ax.set_title('3D Scatter Plot')

# Add a color bar
plt.colorbar(scatter, label='Class')

# Show the plot
plt.show()

# %%
X=data.drop(['target'],axis=1)
y=data[['target']]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Define a range of random state values to try
random_states = range(1, 101)

# Initialize variables to store the best random state and its corresponding accuracy
best_random_state = None
best_accuracy = 0

# Iterate through each random state and train a model
for random_state in random_states:
    # Perform train-test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_state)
    
    # Initialize and train a classifier
    clf = LogisticRegression()
    clf.fit(X_train, y_train)
    
    # Predict on the test set
    y_pred = clf.predict(X_test)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_test, y_pred)
    
    # Check if this random state resulted in a higher accuracy
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_random_state = random_state

# Print the best random state and its corresponding accuracy
print("Best Random State:", best_random_state)
print("Best Accuracy:", best_accuracy)
# Out:
# Best Random State: 90
# Best Accuracy: 0.8848825411691251

# %%
from sklearn.model_selection import train_test_split
#division X_train,X_test,y_train,y_test
#Gen Aleat = random_state
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=59)

# %%
from sklearn.preprocessing import StandardScaler

# Initialize StandardScaler
scaler = StandardScaler()

# Fit StandardScaler to your training data
scaler.fit(X_train)

# Transform both your training and testing data using the fitted StandardScaler
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV

# %%
knn = KNeighborsClassifier()
k_range = list(range(1, 25)) #Number of Clus
#param_grid = dict(n_neighbors=k_range)

param_grid = {
    'n_neighbors': list(range(1, 26)),
    'weights': ['uniform', 'distance'],
}
  
# defining parameter range
grid = GridSearchCV(knn, param_grid, cv=5)
  
# fitting the model for grid search
grid_search=grid.fit(X_train, y_train)

# print the best parameters and the corresponding accuracy score
print('Best Parameters:', grid_search.best_params_)
print('Best Score:', grid_search.best_score_)
# Out:
# Best Parameters: {'n_neighbors': 13, 'weights': 'distance'}
# Best Score: 0.9440953677812706

# %%
print(grid_search.best_params_)
# Out:
# {'n_neighbors': 13, 'weights': 'distance'}

# %%
# best score
grid.best_score_
# Out:
# 0.9440953677812706

# %%
grid.best_estimator_
# Out:
# KNeighborsClassifier(n_neighbors=13, weights='distance')

# %%
# modele final
final_model_knn=grid.best_estimator_

# %%
#y_pred 
y_pred=final_model_knn.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import plot_confusion_matrix, classification_report
# matrices de confusion
plot_confusion_matrix(final_model_knn,X_test,y_test,cmap='Blues')

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11238
#            1       0.90      0.75      0.82      1575
#
#     accuracy                           0.96     12813
#    macro avg       0.93      0.87      0.90     12813
# weighted avg       0.96      0.96      0.96     12813
